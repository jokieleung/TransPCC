# %%
from depoco.plot_results import *
path = '../experiments/results/kitti/original_depoco/'
files = sorted(glob.glob(path+'*.pkl'))
# print(files)

# transPCC_path = '../experiments/results/kitti/bpp_exp/'
transPCC_path = '../experiments/results/kitti/transPCC/'
transPCC_files = sorted(glob.glob(transPCC_path+'*.pkl'))
# print(transPCC_files)

f, ax = plt.subplots(2, 2)
# f, ax = plt.subplots(1)
ax = ax.flatten()
f.suptitle('Kitti Results')
genComparisonPlots2(ax, draw_line=True, label='Draco', x_key='bpp')
genComparisonPlots1(ax, draw_line=True, label='MPEG', x_key='bpp')
genComparisonPlots(ax, draw_line=True, label='Octree', x_key='bpp')
genPlots(files, f, ax, draw_line=True, label='depoco', x_key='bpp')
genPlots(transPCC_files, f, ax, draw_line=True, label='transPCC', x_key='bpp')
# genPlots(transPCC_files, f, ax, draw_line=True, label='transPCC', x_key='bpp')
for a in ax:
    a.grid()
    # a.set_ylim([0,None])
    a.legend()
plt.tight_layout()
plt.show()
# Out:
# WARNING - 2022-01-26 08:11:51,330 - legend - No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ------------------
# depoco
# chamfer_dist_abs
# [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
# [0.10234825112806853, 0.0842990571212384, 0.06794475077060602, 0.06410150742659004]
# ------------------
# depoco
# chamfer_dist_plane
# [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
# [0.0566490256097368, 0.04434283007617279, 0.03274278949585653, 0.030984551515630496]
# ------------------
# depoco
# iou
# [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
# [0.2854602888058237, 0.33740799677839384, 0.3715310179166893, 0.3969374891809744]
# ------------------
# transPCC
# chamfer_dist_abs
# [0.033956612175965135, 0.06791322435193027, 0.13582644870386054, 0.3056095095836862]
# ...

# %%
x1= [0.125, 0.26, 0.651,1.00]
y1= [0.4, 0.218, 0.12,0.1]

x2= [0.125, 0.375, 0.75,1.00]
y2= [0.26, 0.13, 0.108,0.09]

x3= [0.021, 0.194, 0.875,1.25]
y3= [0.25, 0.117, 0.06,0.05]

x4 = [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
y4 = [0.10234825112806853, 0.0842990571212384, 0.06794475077060602, 0.06410150742659004]

x5 = [0.033956612175965135, 0.06791322435193027, 0.13582644870386054, 0.3056095095836862]
y5 = [0.014169056619727803, 0.008367246014356454, 0.006540907374132545, 0.004359445637292279]

l1=plt.plot(x1,y1, '-x',label='Draco')
l2=plt.plot(x2,y2, '-x',label='MPEG')
l3=plt.plot(x3,y3, '-x',label='Octree')
l4=plt.plot(x4,y4, '-x',label='Depoco')
l5=plt.plot(x5,y5, '-x',label='TransPCC')

# # 设置刻度字体大小
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# # 设置坐标标签字体大小
# ax.set_xlabel(..., fontsize=13)
# ax.set_ylabel(..., fontsize=13)
# # 设置图例字体大小
# ax.legend(..., fontsize=13)

plt.xlabel('BPP', fontsize=13)
plt.ylabel('mean Chamfer Distance - L2', fontsize=13)
plt.legend(fontsize=13)
plt.grid()
plt.savefig("chamf_abs.pdf")
plt.show()

# %%
x1= [0.125, 0.26, 0.651,1.00]
y1= [0.225, 0.125, 0.07,0.053]

x2= [0.125, 0.375, 0.75,1.00]
y2= [0.15, 0.055, 0.048,0.038]

x3= [0.021, 0.194, 0.875,1.25]
y3= [0.15, 0.07, 0.035,0.029]

x4 = [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
y4 = [0.0566490256097368, 0.04434283007617279, 0.03274278949585653, 0.030984551515630496]

x5 = [0.033956612175965135, 0.06791322435193027, 0.13582644870386054, 0.3056095095836862]
y5 = [0.00447997387488603, 0.004022340979977881, 0.0031594663310135084, 0.002066976756923982]

l1=plt.plot(x1,y1, '-x',label='Draco')
l2=plt.plot(x2,y2, '-x',label='MPEG')
l3=plt.plot(x3,y3, '-x',label='Octree')
l4=plt.plot(x4,y4, '-x',label='depoco')
l5=plt.plot(x5,y5, '-x',label='transPCC')

# plt.xlabel('bpp')
# plt.ylabel('chamfer_dist_plane')
# plt.legend()
# plt.grid()
# plt.show()


# # 设置刻度字体大小
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# # 设置坐标标签字体大小
# ax.set_xlabel(..., fontsize=13)
# ax.set_ylabel(..., fontsize=13)
# # 设置图例字体大小
# ax.legend(..., fontsize=13)

plt.xlabel('BPP', fontsize=13)
plt.ylabel('plane Chamfer Distance', fontsize=13)
plt.legend(fontsize=13)
plt.grid()
plt.savefig("chamf_plane.pdf")
plt.show()

# %%
x1= [0.125, 0.26, 0.651,1.00]
y1= [0.001, 0.01, 0.11,0.22]

x2= [0.125, 0.375, 0.75,1.00]
y2= [0.04, 0.17, 0.337,0.456]

x3= [0.021, 0.194, 0.875,1.25]
y3= [0.01, 0.12, 0.49,0.55]

x4 = [0.06818547164513165, 0.1535966292284371, 0.4216689442736249, 0.5945043184935671]
y4 = [0.2854602888058237, 0.33740799677839384, 0.3715310179166893, 0.3969374891809744]

x5 = [0.033956612175965135, 0.06791322435193027, 0.13582644870386054, 0.3056095095836862]
y5 = [0.8582546475037458, 0.883594439946797, 0.9132638927887761, 0.9390411240116662]

l1=plt.plot(x1,y1, '-x',label='Draco')
l2=plt.plot(x2,y2, '-x',label='MPEG')
l3=plt.plot(x3,y3, '-x',label='Octree')
l4=plt.plot(x4,y4, '-x',label='Depoco')
l5=plt.plot(x5,y5, '-x',label='TransPCC')

# plt.xlabel('bpp')
# plt.ylabel('iou')
# plt.legend()
# plt.grid()
# plt.show()



# # 设置刻度字体大小
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# # 设置坐标标签字体大小
# ax.set_xlabel(..., fontsize=13)
# ax.set_ylabel(..., fontsize=13)
# # 设置图例字体大小
# ax.legend(..., fontsize=13)

plt.xlabel('BPP', fontsize=13)
plt.ylabel('IoU', fontsize=13)
plt.legend(fontsize=10)
plt.grid()
plt.savefig("iou.pdf")
plt.show()
